# %% [markdown]
# ## Projeto integrado: Análise de uma empresa de E-commerce
# Geração de 48 meses de massa de dados fictícios para uma empresa ficitícia de e-commerce com produtos próprios e marketplace, intitulada Shopnow.

# %%
#Instalando biblioteca para gerar dados fictícios
# !pip install Faker
# Instalando biblioteca para exluir feriados nacionais da data_entrega
# !pip install workalendar

# %%
#Importando bibliotecas
import pandas as pd
import random
import numpy as np
from faker import Faker
from datetime import date, timedelta
from workalendar.america import Brazil

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Informações Gerais:


#Criação de listas vazias para armazenamento dos dados
DATA_PEDIDO = []
CATEGORIA_PRODUTO = []
PRODUTO = []
QTD_PRODUTO = []
VALOR_VENDA = []
FORMA_PAGAMENTO = []
REGISTRO_CLIENTE = []
TIPO_CLIENTE = []
PAIS_CLIENTE = []
ESTADO_CLIENTE = []
CIDADE_CLIENTE = []
CEP_CLIENTE = []
LATITUDE_CLIENTE = []
LONGITUDE_CLIENTE = []
SELLER = []
FORNECECEDOR = []
CANCELAMENTO = []
MOTIVO_CANCELAMENTO = []
DATA_ENTREGA = []
TIPO_ENTREGA = []
CANAL_VENDA = []
AVALIAÇÃO = []
COMISSÃO = []

# Criação de variáveis

categoria_produtos = [
    "PEÇAS INTERNAS AUTO","PEÇAS EXTERNAS AUTO","FERRAMENTAS AUTO",
    "FRALDAS E HIGIENE","ROUPAS INFANTIL","BRINQUEDOS","PERFUMARIA",
    "CUIDADOS COM O CORPO","CUIDADOS COM O ROSTO","ROUPAS DE CAMA",
    "ROUPAS DE BANHO","ROUPAS MESA","TELEFONIA MÓVEL","TELEFONIA FIXA",
    "ACESSÓRIOS TELEFONIA","TELEVISORES","ACESSÓRIOS ELETRÔNICOS","WEARABLES",
    "ROUPAS ESPORTE","CALÇADOS ESPORTE","ACESSÓRIOS ESPORTE","CONSOLES DE GAMES",
    "JOGOS","ACESSÓRIOS CONSOLES","LIVROS","MATERIAL DE ESCRITÓRIO","ARTE E ARTESANATO",
    "NÃO PERECÍVEIS","LIMPEZA E LAVANDERIA","BEBIDAS","NOTEBOOKS E TABLETS","DESKTOPS",
    "MONITORES","MOVEIS SALA","MOVEIS QUARTO","MOVEIS COZINHA","ELETRODOMÉSTICOS COZINHA",
    "UTENSÍLIOS COZINHA","ACESSÓRIOS COZINHA","AR CONDICIONADO","VENTILADOR","PURIFICADOR",
    "GELADEIRA","FOGÃO","MICROONDAS","ROUPAS FEMININAS","ROUPAS MASCULINAS","ROUPAS FITNESS",
    "FASHION BOLSAS E SAPATOS","FERRAMENTAS CONSTRUÇÃO","FERRAMENTAS JARDIM","FERRAMENTAS SEGURANÇA"
]

faixas_de_preco = {
    "FERRAMENTAS AUTO": (25, 1000),"PEÇAS EXTERNAS AUTO": (50, 2000),
    "PEÇAS INTERNAS AUTO": (30, 800),"CUIDADOS COM O CORPO": (5, 500),
    "CUIDADOS COM O ROSTO": (10, 700),"PERFUMARIA": (25, 3000),
    "ROUPAS DE BANHO": (20, 800),"ROUPAS DE CAMA": (30, 600),
    "ROUPAS MESA": (25, 500),"AR CONDICIONADO": (900, 5000),
    "PURIFICADOR": (50, 500),"VENTILADOR": (20, 500),
    "ACESSÓRIOS CONSOLES": (10, 500),"CONSOLES DE GAMES": (1000, 5000),
    "FASHION BOLSAS E SAPATOS":(100,500), "JOGOS": (50, 500),
    "FERRAMENTAS CONSTRUÇÃO": (10, 2000),
    "FERRAMENTAS JARDIM": (10, 1000),"FERRAMENTAS SEGURANÇA": (500, 1000),
    "FOGÃO": (300, 1500),"GELADEIRA": (500, 3000),"MICROONDAS": (100, 400),
    "ACESSÓRIOS ELETRÔNICOS": (10, 1500),"TELEVISORES": (1000, 8000),
    "WEARABLES": (500, 1000),"ACESSÓRIOS ESPORTE": (20, 800),
    "CALÇADOS ESPORTE": (100, 1000),"ROUPAS ESPORTE": (100, 800),
    "ROUPAS FEMININAS": (100, 800),"ROUPAS FITNESS": (100, 800),
    "ROUPAS MASCULINAS": (100, 800),"BEBIDAS": (5, 400),
    "LIMPEZA E LAVANDERIA": (5, 500),"NÃO PERECÍVEIS": (5, 100),
    "BRINQUEDOS": (10, 1000),"FRALDAS E HIGIENE": (10, 200),
    "ROUPAS INFANTIL": (10, 400),"ACESSÓRIOS COZINHA": (5, 500),
    "ELETRODOMÉSTICOS COZINHA": (100, 1000),"UTENSÍLIOS COZINHA": (5, 300),
    "ARTE E ARTESANATO": (10, 500),"LIVROS": (10, 500),
    "MATERIAL DE ESCRITÓRIO": (5, 700),"MOVEIS COZINHA": (1000, 4000),
    "MOVEIS QUARTO": (2000, 5000),"MOVEIS SALA": (1000, 3000),
    "DESKTOPS": (500, 3000),"MONITORES": (1000, 4000),
    "NOTEBOOKS E TABLETS": (1000, 5000),"ACESSÓRIOS TELEFONIA": (20, 500),
    "TELEFONIA FIXA": (50, 500),"TELEFONIA MÓVEL": (1000, 8000)
}

produtos_por_categoria = {
    "FERRAMENTAS AUTO": ["Jogo de chaves de fenda", "Compressor de ar", "Macaco hidráulico", "Lanterna recarregável", "Kit de ferramentas automotivas"],
    "PEÇAS EXTERNAS AUTO": ["Faróis LED", "Protetor de capô", "Calotas decorativas", "Kit de polimento automotivo", "Kit de proteção para pneus"],
    "PEÇAS INTERNAS AUTO": ["Tapetes de carro", "Volante esportivo", "Capa de assento", "Kit de iluminação interior", "Jogo de tapetes de porta"],
    "CUIDADOS COM O CORPO": ["Sabonete líquido", "Creme hidratante corporal", "Desodorante roll-on", "Escova de banho", "Esponja de banho"],
    "CUIDADOS COM O ROSTO": ["Creme facial anti-idade", "Gel de limpeza facial", "Tônico facial", "Máscara facial", "Protetor solar facial"],
    "PERFUMARIA": ["Perfume masculino", "Perfume feminino", "Perfume unissex", "Kit de fragrâncias", "Óleo perfumado para o corpo"],
    "ROUPAS DE BANHO": ["Toalhas de banho", "Roupão de banho", "Chinelo de banho", "Cortina de banho", "Tapete para banheiro"],
    "ROUPAS DE CAMA": ["Jogo de lençóis", "Edredom", "Fronhas decorativas", "Colcha de cama", "Cobertor de microfibra"],
    "ROUPAS MESA": ["Jogo de toalhas de mesa", "Guardanapos de pano", "Porta-guardanapos", "Jogo americano", "Trilho de mesa"],
    "AR CONDICIONADO": ["Ar-condicionado split", "Ar-condicionado portátil", "Ar-condicionado janela", "Controle remoto universal para ar-condicionado", "Suporte de parede para ar-condicionado"],
    "PURIFICADOR": ["Purificador de ar HEPA", "Purificador de ar com ionizador", "Filtro de reposição para purificador", "Purificador de ar para carros", "Purificador de ar com aromaterapia"],
    "VENTILADOR": ["Ventilador de mesa", "Ventilador de torre", "Ventilador de teto", "Ventilador de parede", "Ventilador portátil"],
    "ACESSÓRIOS CONSOLES": ["Controle sem fio para console", "Capa protetora para controle", "Cabo HDMI de alta velocidade", "Suporte de carregamento para controle", "Fone de ouvido gamer"],
    "CONSOLES DE GAMES": ["Console de videogame", "Console portátil", "Kit de jogos para console"],
    "JOGOS": ["Jogo de videogame para Xbox/PlayStation/PC", "Console portátil de jogos", "Assinatura de serviço de jogos online", "Controle para videogame", "Headset gamer"],
    "FERRAMENTAS CONSTRUÇÃO": ["Furadeira elétrica", "Serra circular", "Kit de ferramentas de construção", "Martelo de carpinteiro", "Nível a laser"],
    "FERRAMENTAS JARDIM": ["Cortador de grama elétrico", "Aparador de grama", "Kit de ferramentas de jardinagem", "Regador automático", "Triturador de galhos"],
    "FERRAMENTAS SEGURANÇA": ["Câmera de segurança Wi-Fi", "Trava de segurança para portas", "Sistema de alarme residencial", "Kit de extintores de incêndio", "Cofre de segurança"],
    "FOGÃO": ["Fogão a gás de 4 bocas", "Fogão elétrico de indução", "Fogão a lenha", "Fogão de embutir", "Forno elétrico embutido"],
    "GELADEIRA": ["Geladeira duplex", "Geladeira side by side", "Geladeira com dispenser de água", "Geladeira compacta", "Geladeira retro"],
    "MICROONDAS": ["Forno de micro-ondas de 20 litros", "Micro-ondas com grill", "Micro-ondas embutido", "Micro-ondas com função de cozimento a vapor", "Micro-ondas compacto"],
    "ACESSÓRIOS ELETRÔNICOS": ["Fones de ouvido sem fio", "Carregador sem fio para smartphones", "Capa protetora para celular", "Bateria externa portátil", "Cabo HDMI de alta velocidade"],
    "TELEVISORES": ["TV LED 4K de 55 polegadas", "TV OLED de 65 polegadas", "TV QLED de 75 polegadas", "TV 8K de 85 polegadas", "Suporte de parede para TV"],
    "WEARABLES": ["Smartwatch", "Rastreador de fitness", "Fones de ouvido esportivos sem fio", "Óculos de realidade virtual", "Pulseira de atividade"],
    "ACESSÓRIOS ESPORTE": ["Bola de futebol", "Raquete de tênis", "Garrafa de água esportiva", "Tapete de yoga", "Tênis para esportes indoor"],
    "CALÇADOS ESPORTE": ["Tênis de corrida", "Sapatos de basquete", "Chuteiras de futebol", "Sapatilhas de balé", "Chinelos esportivos"],
    "ROUPAS ESPORTE": ["Camiseta esportiva", "Leggings de ginástica", "Shorts de corrida", "Jaqueta corta-vento", "Top de esporte"],
    "ROUPAS FEMININAS": ["Vestido de verão", "Blusa de manga longa", "Saia midi", "Calças de alfaiataria", "Casaco de inverno"],
    "ROUPAS FITNESS": ["Conjunto de roupas de academia", "Leggings esportivas", "Top esportivo", "Shorts de ginástica", "Camiseta dry-fit"],
    "ROUPAS MASCULINAS": ["Camisa social", "Calça jeans", "Camiseta polo", "Terno completo", "Jaqueta de couro"],
    "BEBIDAS": ["Vinho tinto", "Cerveja artesanal", "Água mineral", "Refrigerante", "Suco de frutas"],
    "LIMPEZA E LAVANDERIA": ["Detergente líquido", "Sabão em pó", "Amaciante de roupas", "Vassoura e pá", "Mop de limpeza"],
    "NÃO PERECÍVEIS": ["Arroz", "Feijão", "Massa", "Enlatados", "Óleo de cozinha"],
    "BRINQUEDOS": ["Quebra-cabeça", "Boneca", "Carrinho de controle remoto", "Bicicleta infantil", "Blocos de construção"],
    "FRALDAS E HIGIENE": ["Fraldas descartáveis", "Lenços umedecidos", "Shampoo para bebês", "Creme para assaduras", "Sabonete líquido infantil"],
    "ROUPAS INFANTIL": ["Macacão com pé", "Conjunto de moletom", "Vestido estampado", "Body manga longa", "Camisetas estampadas"],
    "ACESSÓRIOS COZINHA": ["Panela de pressão", "Jogo de facas", "Liquidificador", "Frigideira antiaderente", "Conjunto de potes de vidro"],
    "ELETRODOMÉSTICOS COZINHA": ["Máquina de café expresso", "Liquidificador de alta potência", "Forno elétrico", "Torradeira", "Máquina de lavar louça"],
    "UTENSÍLIOS COZINHA": ["Conjunto de utensílios de aço inoxidável", "Escorredor de macarrão", "Tábua de corte de madeira", "Ralador de queijo", "Afiador de facas"],
    "ARTE E ARTESANATO": ["Conjunto de tintas acrílicas", "Pincéis para pintura", "Papel para aquarela", "Modelagem em argila", "Kit de bordado"],
    "LIVROS": ["Romance best-seller", "Livro de não-ficção", "Livro de autoajuda", "Livro infantil ilustrado", "Coleção de clássicos literários"],
    "MATERIAL DE ESCRITÓRIO": ["Canetas coloridas", "Cadernos pautados", "Agenda de planejamento", "Pasta organizadora de documentos", "Calculadora científica"],
    "MOVEIS COZINHA": ["Jogo de mesa e cadeiras de jantar", "Buffet de cozinha", "Armário de cozinha", "Bancada de cozinha", "Cadeiras de bar"],
    "MOVEIS QUARTO": ["Cama king-size com cabeceira estofada", "Guarda-roupa de madeira maciça", "Cômoda com espelho", "Mesa de cabeceira moderna", "Escrivaninha para escritório em casa"],
    "MOVEIS SALA": ["Sofá de couro reclinável", "Mesa de centro de vidro temperado", "Estante de madeira maciça", "Rack de TV com painel suspenso", "Poltrona de design elegante"],
    "DESKTOPS": ["Desktop gaming de alta performance", "Computador all-in-one com tela touch", "Desktop compacto para escritório", "Workstation para design gráfico", "Desktop para uso doméstico"],
    "MONITORES": ["Monitor LED de 27 polegadas com resolução 4K", "Monitor curvo de 34 polegadas para jogos", "Monitor ultrawide de 29 polegadas", "Monitor de design profissional com calibração de cores", "Monitor portátil USB-C de 15 polegadas"],
    "NOTEBOOKS E TABLETS": ["Notebook ultrafino com processador potente", "Tablet Android de última geração", "Notebook 2 em 1 com tela sensível ao toque", "Notebook para jogos de alta performance", "Tablet gráfico para ilustração digital"],
    "ACESSÓRIOS TELEFONIA": ["Capa protetora para celular", "Fone de ouvido Bluetooth com cancelamento de ruído", "Carregador sem fio para smartphone", "Película de vidro temperado para tela de celular", "Suporte para carro para celular"],
    "TELEFONIA FIXA": ["Telefone sem fio com identificador de chamadas", "Telefone com fio para escritório", "Telefone com viva-voz e secretária eletrônica", "Telefone sem fio com dois ramais", "Telefone fixo com teclas grandes para idosos"],
    "TELEFONIA MÓVEL": ["Smartphone topo de linha", "Celular desbloqueado com Android", "iPhone mais recente", "Smartphone resistente à água e poeira", "Celular básico com longa duração da bateria"],
    "FASHION BOLSAS E SAPATOS": ["Bolsa Ecológica","Bolsa Crossbody", "Clutch de Noite","Mochila Multifuncional","Bolsa de Couro", "Tênis Esportivos", "Sapatilhas de Ballet ","Botas de Cano Alto","Chinelos", "Sapatos Oxford"]
}

forma_pagamento = {
    "Cartão de Crédito", "Cartão de Débito", "PIX", "Boleto"
}

tipo_cliente = {
    "Prime", "Não prime"
}

motivo_cancelamento = {
    "Defeito", "Problemas na entrega", "Arrependimento da Compra", "Produto diferente da foto"
 }

tipo_entrega_1P = {
    "Correios", "Shopnow entrega"
 }

tipo_entrega_3P = {
    "Correios", "Shopnow entrega", "seller"
 }
canal_venda = {
    "Website", "App", "Social Media", "Chatbots", "Telemarketing"
}

comentários = {"Péssimo", "Ruim", "Mediano", "Bom", "Excelente"}

seller = "Shopnow"

#Faker para geração de dados fictícios
fake = Faker('pt_BR')

#Definição do perído de 48 meses
data_inicio = date(2019, 1, 1)
data_fim = date(2022, 12, 31)

#Lista de Feriados entre 2019 e 2023 para desconsiderar na data_entrega
cal = Brazil()
anos = [2019,2020,2021,2022,2023]
feriados = []
for ano in anos:
 feriados_ano = cal.holidays(ano)
 feriados.extend(feriados_ano)

# Definição de função
def gera_arr_cliente(size, dfamostras):
  arr = []
  count = 0
  while len(arr)<size:
    registro_cliente = fake.random_int(100000, 999999)
    cep = dfamostras['ZIPCODE'].iloc[count]
    estado = dfamostras['STATE'].iloc[count]
    cidade = dfamostras['CITY'].iloc[count]
    latitude = dfamostras['LATITUDE'].iloc[count]
    longitude = dfamostras['LONGITUDE'].iloc[count]
    client_r = registro_cliente
    count +=1
    for i in range(1, fake.random_int(2, 10)):
      if len(arr)==size:
        return arr
      else:
        arr.append({
            "cep": cep,
            "estado": estado,
            "cidade": cidade,
            "latitude": latitude,
            "longitude": longitude,
            "cliente": client_r
          })
  return arr
# Lógica
total_registros = 400000
df = pd.read_csv ('/content/drive/MyDrive/PUC/Projeto-integrado/geolocalização_dataset.csv', sep=';')
dfamostras = df.sample(n= total_registros+5)
contador = 0
porcentagem_cancelamento = 0.07
max_cancelamentos = int(total_registros * porcentagem_cancelamento)
n_cancelados = ["Cancelado"]
n_nao_cancelados = ["Ativo"]
x = np.repeat(n_cancelados, max_cancelamentos)
y = np.repeat(n_nao_cancelados, total_registros-max_cancelamentos)
cancelamentos = [*x, *y]
random.shuffle(cancelamentos)
arr_clientes = gera_arr_cliente(total_registros, dfamostras)
while contador < total_registros:

#Memória Cálculo:
  #Data pedido
  data_pedido = fake.date_between(start_date=data_inicio, end_date=data_fim)
  #Categoria
  categoria = fake.word(ext_word_list=categoria_produtos)
  #Produto
  produto = fake.random_element(elements=produtos_por_categoria[categoria])
  #Valor venda
  min_valor, max_valor = faixas_de_preco[categoria]
  valor_venda = fake.random_int(min_valor, max_valor)
  #Data entrega
  data_entrega_minima = data_pedido + timedelta(days=1)
  data_entrega_maxima = data_pedido + timedelta(days=10)
  data_entrega = fake.date_between(start_date=data_entrega_minima, end_date=data_entrega_maxima)
  nao_tiver_data_correta = True
  while nao_tiver_data_correta:
    if data_entrega in feriados:
     data_entrega = fake.date_between(start_date=data_entrega_minima, end_date=data_entrega_maxima)
    else:
      nao_tiver_data_correta = False
  #Cancelamento
  cancelamento = cancelamentos[contador]
  if cancelamento == "Cancelado":
      data_entrega = "1900-01-01"
  #Motivo cancelamento
      motivo = fake.random_element(elements=motivo_cancelamento)
  else:
      motivo = "nenhum"
  #Avaliações
  if data_entrega != "1900-01-01":
    avaliações = fake.random_element(elements=comentários)
  else:
    avaliações = "nenhum"
  #Informações cliente
  cliente = arr_clientes[contador]
  cep = cliente['cep']
  estado = cliente['estado']
  cidade = cliente['cidade']
  latitude = cliente['latitude']
  longitude = cliente['longitude']
  registro_cliente = cliente['cliente']
  #Fornecedor
  fornecedor = fake.company()
  #Seller
  if contador > 170000:
    seller = fake.company()
    fornecedor = "nenhum"
  #Tipo entrega
  if data_entrega != "1900-01-01" and seller == "Shopnow":
    tipo_entrega = fake.random_element(elements=tipo_entrega_1P)
  elif data_entrega != "1900-01-01" and seller != "Shopnow":
    tipo_entrega = fake.random_element(elements=tipo_entrega_3P)
  else:
    tipo_entrega = "nenhum"
  #Comissão
  if data_entrega != "1900-01-01" and seller != "Shopnow":
    comissao = int(valor_venda*0.1)
  else:
   comissao = 0

  #Alocação dos dados nas listas
  DATA_PEDIDO.append(data_pedido)
  CATEGORIA_PRODUTO.append(categoria)
  PRODUTO.append(produto)
  QTD_PRODUTO.append(random.randint(1, 4))
  VALOR_VENDA.append(valor_venda)
  DATA_ENTREGA.append(data_entrega)
  FORMA_PAGAMENTO.append(fake.random_element(elements=forma_pagamento))
  TIPO_CLIENTE.append(fake.random_element(elements=tipo_cliente))
  REGISTRO_CLIENTE.append(registro_cliente)
  PAIS_CLIENTE.append("Brasil")
  ESTADO_CLIENTE.append(estado)
  CIDADE_CLIENTE.append(cidade)
  CEP_CLIENTE.append(cep)
  LATITUDE_CLIENTE.append(latitude)
  LONGITUDE_CLIENTE.append(longitude)
  SELLER.append(seller)
  FORNECECEDOR.append(fornecedor)
  CANCELAMENTO.append(cancelamento)
  MOTIVO_CANCELAMENTO.append(motivo)
  TIPO_ENTREGA.append(tipo_entrega)
  CANAL_VENDA.append(fake.random_element(elements=canal_venda))
  AVALIAÇÃO.append(avaliações)
  COMISSÃO.append(comissao)

  contador += 1

#Criando um dicionário com os dados
data = {
    'DATA_PEDIDO': DATA_PEDIDO,
    'CATEGORIA_PRODUTO': CATEGORIA_PRODUTO,
    'PRODUTO': PRODUTO,
    'QTD_PRODUTO': QTD_PRODUTO,
    'VALOR_VENDA': VALOR_VENDA,
    'FORMA_PAGAMENTO': FORMA_PAGAMENTO,
    'DATA_ENTREGA': DATA_ENTREGA,
    'TIPO_CLIENTE': TIPO_CLIENTE,
    'REGISTRO_CLIENTE': REGISTRO_CLIENTE,
    'PAIS_CLIENTE': PAIS_CLIENTE,
    'ESTADO_CLIENTE': ESTADO_CLIENTE,
    'CIDADE_CLIENTE': CIDADE_CLIENTE,
    'CEP_CLIENTE': CEP_CLIENTE,
    'LATITUDE_CLIENTE': LATITUDE_CLIENTE,
    'LONGITUDE_CLIENTE': LONGITUDE_CLIENTE,
    'SELLER': SELLER,
    'FORNECEDOR': FORNECECEDOR,
    'CANCELAMENTO': CANCELAMENTO,
    'MOTIVO_CANCELAMENTO': MOTIVO_CANCELAMENTO,
    'TIPO_ENTREGA': TIPO_ENTREGA,
    'CANAL_VENDA': CANAL_VENDA,
    'AVALIAÇÃO': AVALIAÇÃO,
    'COMISSÃO': COMISSÃO
}

df = pd.DataFrame(data)

df.to_csv('dados_shopnow_3.csv', index=False, encoding='utf-8', quoting=1)
from google.colab import files
files.download('dados_shopnow_3.csv')
